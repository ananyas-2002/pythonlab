# %%
n=int(input("enter size of list:"))
lst1=[]
for i in range(n):
    ele=int(input("enter list elements:"))
    lst1.append(ele)
print("lList1:",lst1)
while(1):
    print("Select Choice:")
    print("\n1.Insert\n2.Remove\n3.Append\n4.Length\n5.Pop\n6.clear\n7.Exit")
    ch=int(input("enter your choice:"))
    if ch==1:
        index=int(input("enter index:"))
        val=int(input("enter value to the list:"))
        lst1.insert(index,val)
        print("List1 after inserting a element:",lst1)
    elif ch==2:
        val=int(input("enter value to remove from list:"))
        if val in lst1:
            lst1.remove(val)
            print("List after removing an element:",lst1)
        else:
            print("Entered value not present in the list*")
    elif ch==3:
        ele=int(input("enter element to append to list:"))
        lst1.append(ele)
        print("List1 after appending:",lst1)
    elif ch==4:
        print("Length of the list1:",len(lst1))
    elif ch==5:
        index=int(input("enter index to pop from the list:"))
        if(index!=0):
            lst1.pop(index)
        print("List after pop giving particular index:",lst1)
        if len(lst1)==0:
            print("You cannot pop from the list,List is empty")
        else:    
            lst1.pop()
            print("List after pop(without giving index):",lst1)
    elif ch==6:
        print("List after clear:",lst1.clear())
    elif ch==7:
        break
    else:
        print("Invalid choice:")
# Out:
# enter size of list:5
# enter list elements:2
# enter list elements:7
# enter list elements:1
# enter list elements:9
# enter list elements:12
# lList1: [2, 7, 1, 9, 12]
# Select Choice:
#
# 1.Insert
# 2.Remove
# 3.Append
# 4.Length
# 5.Pop
# 6.clear
# 7.Exit
# enter your choice:1
# enter index:2
# enter value to the list:7
# List1 after inserting a element: [2, 7, 7, 1, 9, 12]
# Select Choice:
#
# 1.Insert
# 2.Remove
# 3.Append
# 4.Length
# 5.Pop
# 6.clear
# 7.Exit
# enter your choice:2
# enter value to remove from list:7
# List after removing an element: [2, 7, 1, 9, 12]
# Select Choice:
#
# 1.Insert
# 2.Remove
# 3.Append
# 4.Length
# 5.Pop
# 6.clear
# 7.Exit
# enter your choice:1
# enter index:2
# enter value to the list:78
# List1 after inserting a element: [2, 7, 78, 1, 9, 12]
# Select Choice:
#
# 1.Insert
# 2.Remove
# 3.Append
# 4.Length
# 5.Pop
# 6.clear
# 7.Exit
# enter your choice:3
# enter element to append to list:88
# List1 after appending: [2, 7, 78, 1, 9, 12, 88]
# Select Choice:
#
# 1.Insert
# 2.Remove
# 3.Append
# 4.Length
# 5.Pop
# 6.clear
# 7.Exit
# enter your choice:4
# Length of the list1: 7
# Select Choice:
#
# 1.Insert
# 2.Remove
# 3.Append
# 4.Length
# 5.Pop
# 6.clear
# 7.Exit
# enter your choice:5
# enter index to pop from the list:3
# List after pop giving particular index: [2, 7, 78, 9, 12, 88]
# List after pop(without giving index): [2, 7, 78, 9, 12]
# Select Choice:
#
# 1.Insert
# 2.Remove
# 3.Append
# 4.Length
# 5.Pop
# 6.clear
# 7.Exit
# enter your choice:6
# List after clear: None
# Select Choice:
#
# 1.Insert
# 2.Remove
# 3.Append
# 4.Length
# 5.Pop
# 6.clear
# 7.Exit
# enter your choice:7

# %%
txt1=input("Enter string1:")
txt2=input("Enter string2:")
print("Text1:",txt1)
print("Text2:",txt2)
txt3=txt1+txt2
print("Concatenated string:",txt3)
print("Substring of the concatenated string is:",txt3[4:15])
print("Length of the given string1:",len(txt1))
print("Length of the given string2:",len(txt2))
print("Length of the concatenated string:",len(txt3))
print("Length of the given substring:",len(txt3[4:15]))
i=input("Enter character to find the index")
if i in txt3:
    print("index of",i,"is:",txt3.index(i))
else:
    print("Entered character not found in the string")
print("Slicing of concatenated string is:",txt3[6:])
if txt1==txt2:
    print("Two strings are equal")
else:
    print("Two strings are not equal")
# Out:
# Enter string1:Hello!
# Enter string2:Very good morning
# Text1: Hello!
# Text2: Very good morning
# Concatenated string: Hello!Very good morning
# Substring of the concatenated string is: o!Very good
# Length of the given string1: 6
# Length of the given string2: 17
# Length of the concatenated string: 23
# Length of the given substring: 11
# Enter character to find the indexv
# Entered character not found in the string
# Slicing of concatenated string is: Very good morning
# Two strings are not equal
